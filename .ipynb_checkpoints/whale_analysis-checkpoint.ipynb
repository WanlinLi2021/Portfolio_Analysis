# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  We will evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P TSX 60 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, we will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp_tsx_history.csv`: Contains historical closing prices of the S&P TSX 60 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data.

# %%
whale_return_data = Path("./Resources/whale_returns.csv")

# %%
whale_return = pd.read_csv(whale_return_data, index_col = "Date", infer_datetime_format = True, parse_dates = True).sort_index()

# %%
# Reading whale returns
whale_return.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_return.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_return.dropna(inplace=True)

# %%
whale_return.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data.

# %%
# Reading algorithmic returns
algo_returns = pd.read_csv(Path("./Resources/algo_returns.csv"), index_col = "Date", infer_datetime_format = True, parse_dates = True).sort_index()

# %%
# Count nulls
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_returns.dropna(inplace=True)

# %%
algo_returns.head(10)
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# 2014-06-12 -0.000028 -0.003841
# 2014-06-13  0.001917 -0.000814
# 2014-06-16  0.001084  0.001831
# 2014-06-17  0.000922  0.006870
# 2014-06-18 -0.006303  0.007228

# %% [markdown]
# ## S&P TSX 60 Returns
#
# Read the S&P TSX 60 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P TSX 60 Closing Prices
sp_tsx_history = pd.read_csv(Path("./Resources/sp_tsx_history.csv"), index_col = "Date", infer_datetime_format = True, parse_dates = True).sort_index()

# %%
# Check Data Types
sp_tsx_history.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp_tsx_history['Close'] = sp_tsx_history['Close'].str.replace('[\$\,]','').astype(float)

# %%
# Calculate Daily Returns
sp_tsx_history = sp_tsx_history.pct_change()

# %%
# Drop nulls
sp_tsx_history.dropna(inplace=True)

# %%
# Rename `Close` Column to be specific to this portfolio.
sp_tsx_history.rename(columns = {'Close':'sp_tsx'}, inplace=True)

# %%
sp_tsx_history.head()
# Out:
#               sp_tsx
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
portfolios_returns = pd.concat([whale_return,algo_returns,sp_tsx_history], axis = 'columns',join = 'inner')
portfolios_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
portfolios_returns.plot(title='Daily returns of all portfolios', figsize=(25, 15))
# Out:
# <AxesSubplot:title={'center':'Daily returns of all portfolios'}, xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
cumulate_returns = (1 + portfolios_returns).cumprod() -1
cumulate_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.000962           -0.001755
# 2015-03-05                   0.004981            0.002314
# 2015-03-06                  -0.002963           -0.001269
# 2015-03-09                  -0.002383            0.002951
# ...                               ...                 ...
# 2019-04-25                   0.118163           -0.245179
# 2019-04-26                   0.127275           -0.238264
# 2019-04-29                   0.128689           -0.236192
# 2019-04-30                   0.127228           -0.237881
# 2019-05-01                   0.120637           -0.238904
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.003028               -0.002383 -0.010514
# ...

# %%
# Plot cumulative returns
cumulate_returns.plot(title='Cumulative returns of all portfolios', figsize=(25, 15))
# Out:
# <AxesSubplot:title={'center':'Cumulative returns of all portfolios'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios.
# 4. Determine which portfolios are riskier than the S&P TSX 60.
# 5. Calculate the Annualized Standard Deviation.

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
portfolios_returns.plot(kind='box', title='Daily returns of all portfolios', figsize=(25, 10))
# Out:
# <AxesSubplot:title={'center':'Daily returns of all portfolios'}>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
portfolios_std = portfolios_returns.std()
portfolios_std.sort_values()
# Out:
# PAULSON & CO.INC.              0.006982
# sp_tsx                         0.007034
# Algo 1                         0.007589
# SOROS FUND MANAGEMENT LLC      0.007828
# Algo 2                         0.008326
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
# Calculate  the daily standard deviation of S&P TSX 60
print(f"daily standard deviation of S&P TSX 60 is {portfolios_std.sp_tsx}")
# Determine which portfolios are riskier than the S&P TSX 60
high_std_index = np.where(portfolios_std>portfolios_std.sp_tsx)
high_std = [portfolios_std[i] for i in high_std_index]
print("\nPrtfolios iskier than the S&P TSX 60 are:")
print(*high_std, sep='\n')
# Out:
# daily standard deviation of S&P TSX 60 is 0.007034167748577725
#
# Prtfolios iskier than the S&P TSX 60 are:
# SOROS FUND MANAGEMENT LLC      0.007828
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# Algo 1                         0.007589
# Algo 2                         0.008326
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
portfolios_returns.std()*np.sqrt(252)
# Out:
# SOROS FUND MANAGEMENT LLC      0.124259
# PAULSON & CO.INC.              0.110841
# TIGER GLOBAL MANAGEMENT LLC    0.172759
# BERKSHIRE HATHAWAY INC         0.203599
# Algo 1                         0.120470
# Algo 2                         0.132177
# sp_tsx                         0.111664
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window.
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P TSX 60.
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta for it and the S&P TSX 60.

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
df_rolling21 = portfolios_returns.rolling(window=21).std()
# Plot the rolling standard deviation
df_rolling21.plot(title='rolling standard deviation for all portfolios', figsize=(25, 15))
# Out:
# <AxesSubplot:title={'center':'rolling standard deviation for all portfolios'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation

df_corr = portfolios_returns.corr()
# Display de correlation matrix
sns.heatmap(df_corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %%
portfolios_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %%
portfolio_lt = portfolios_returns.columns.tolist()[:-1]
portfolio_lt
# Out:
# ['SOROS FUND MANAGEMENT LLC',
#  'PAULSON & CO.INC. ',
#  'TIGER GLOBAL MANAGEMENT LLC',
#  'BERKSHIRE HATHAWAY INC',
#  'Algo 1',
#  'Algo 2']

# %%
# Calculate covariance of a single portfolio
covariance = [portfolios_returns[x].cov(portfolios_returns['sp_tsx']) for x in portfolio_lt]
covariance
# Out:
# [3.7106899078552405e-05,
#  2.3894916563613552e-05,
#  3.37272414943551e-05,
#  5.027336077110027e-05,
#  1.6563000308911453e-05,
#  4.3187044300842764e-05]

# %%
# Calculate variance of S&P TSX
variance = portfolios_returns['sp_tsx'].var()
variance
# Out:
# 4.9479515915131015e-05

# %%
# Computing beta
beta = [cov/variance for cov in covariance]
beta_dict = dict(zip(portfolio_lt,beta))
beta_dict
# Out:
# {'SOROS FUND MANAGEMENT LLC': 0.7499446668435368,
#  'PAULSON & CO.INC. ': 0.4829254312956283,
#  'TIGER GLOBAL MANAGEMENT LLC': 0.6816404904244665,
#  'BERKSHIRE HATHAWAY INC': 1.016043909106364,
#  'Algo 1': 0.33474459081857,
#  'Algo 2': 0.8728267344999633}

# %%
# Plot beta trend
# choose the portfolio with minimum beta for visualization --- Algo 1 
sns.lmplot(x='sp_tsx', y= 'Algo 1', data= portfolios_returns, aspect=1.5, fit_reg=True)

# %%
sns.lmplot(x='sp_tsx', y= 'Algo 2', data= portfolios_returns, aspect=1.5, fit_reg=True)

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it **assigns greater importance to more recent observations**. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
portfolios_returns.ewm(span=21).std().plot(figsize= (25,15))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
# Assuming the guaranteed return is 0
sharp_ratios = ((portfolios_returns.mean()-0)*252)/(portfolios_returns.std()*np.sqrt(252))
sharp_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.286709
# PAULSON & CO.INC.             -0.547594
# TIGER GLOBAL MANAGEMENT LLC   -0.144455
# BERKSHIRE HATHAWAY INC         0.467045
# Algo 1                         1.491514
# Algo 2                         0.396817
# sp_tsx                         0.195550
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharp_ratios.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.
#
# Algo 1, with highest Sharpe Radio, shows a high excess reward after tisk has benn accounted for. In addition, with the lowerest Beta value (0.335), Algo 1 is less volatile and uncorrelated to the market.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P TSX 60.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock.
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns.
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others.
# 5. Include correlation analysis to determine which stocks (if any) are correlated.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
l = pd.read_csv(Path("./Resources/l_historical.csv"), index_col = "Date", infer_datetime_format = True, parse_dates = True).sort_index()
l.rename(columns={'Close':'L'}, inplace = True)
l.head()
# Out:
#            Symbol      L
# Date
# 2018-01-02      L  57.99
# 2018-01-03      L  57.41
# 2018-01-04      L  57.42
# 2018-01-05      L  57.42
# 2018-01-08      L  56.86

# %%
# Reading data from 2nd stock
otex = pd.read_csv(Path("./Resources/otex_historical.csv"), index_col = "Date", infer_datetime_format = True, parse_dates = True).sort_index()
otex.rename(columns={'Close':'OTEX'}, inplace = True)
otex.head()
# Out:
#            Symbol   OTEX
# Date
# 2018-01-02   OTEX  43.58
# 2018-01-03   OTEX  43.07
# 2018-01-04   OTEX  42.91
# 2018-01-05   OTEX  42.57
# 2018-01-08   OTEX  42.16

# %%
# Reading data from 3rd stock
shop = pd.read_csv(Path("./Resources/shop_historical.csv"), index_col = "Date", infer_datetime_format = True, parse_dates = True).sort_index()
shop.rename(columns={'Close':'SHOP'}, inplace = True)
shop.head()
# Out:
#            Symbol    SHOP
# Date
# 2018-01-02   SHOP  132.06
# 2018-01-03   SHOP  135.15
# 2018-01-04   SHOP  137.46
# 2018-01-05   SHOP  137.26
# 2018-01-08   SHOP  139.51

# %%
# Combine all stocks in a single DataFrame
my_portfolio = pd.concat([l,otex,shop], axis = 'columns',join = 'inner')
my_portfolio
# Out:
#            Symbol      L Symbol   OTEX Symbol    SHOP
# Date
# 2018-01-02      L  57.99   OTEX  43.58   SHOP  132.06
# 2018-01-03      L  57.41   OTEX  43.07   SHOP  135.15
# 2018-01-04      L  57.42   OTEX  42.91   SHOP  137.46
# 2018-01-05      L  57.42   OTEX  42.57   SHOP  137.26
# 2018-01-08      L  56.86   OTEX  42.16   SHOP  139.51
# ...           ...    ...    ...    ...    ...     ...
# 2019-12-20      L  67.90   OTEX  58.68   SHOP  513.22
# 2019-12-23      L  67.68   OTEX  57.89   SHOP  511.62
# 2019-12-24      L  67.67   OTEX  57.44   SHOP  525.39
# 2019-12-27      L  67.78   OTEX  57.70   SHOP  534.76
# 2019-12-30      L  67.33   OTEX  57.19   SHOP  517.79
#
# [501 rows x 6 columns]

# %%
# drop unnecessary columns
my_portfolio.drop('Symbol', axis=1, inplace=True)
my_portfolio
# Out:
#                 L   OTEX    SHOP
# Date
# 2018-01-02  57.99  43.58  132.06
# 2018-01-03  57.41  43.07  135.15
# 2018-01-04  57.42  42.91  137.46
# 2018-01-05  57.42  42.57  137.26
# 2018-01-08  56.86  42.16  139.51
# ...           ...    ...     ...
# 2019-12-20  67.90  58.68  513.22
# 2019-12-23  67.68  57.89  511.62
# 2019-12-24  67.67  57.44  525.39
# 2019-12-27  67.78  57.70  534.76
# 2019-12-30  67.33  57.19  517.79
#
# [501 rows x 3 columns]

# %%
# Calculate daily returns
my_portfolio = my_portfolio.sort_index()
my_portfolio_returns = my_portfolio.pct_change()
# Drop NAs
my_portfolio_returns.dropna(inplace=True)
my_portfolio_returns
# Out:
#                    L      OTEX      SHOP
# Date
# 2018-01-03 -0.010002 -0.011703  0.023398
# 2018-01-04  0.000174 -0.003715  0.017092
# 2018-01-05  0.000000 -0.007924 -0.001455
# 2018-01-08 -0.009753 -0.009631  0.016392
# 2018-01-09  0.008969 -0.000712 -0.011254
# ...              ...       ...       ...
# 2019-12-20  0.003547  0.024441 -0.005503
# 2019-12-23 -0.003240 -0.013463 -0.003118
# 2019-12-24 -0.000148 -0.007773  0.026915
# 2019-12-27  0.001626  0.004526  0.017834
# 2019-12-30 -0.006639 -0.008839 -0.031734
#
# [500 rows x 3 columns]

# %%
# Display sample data
my_portfolio_returns.plot(figsize=(25, 15))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
weighted_returns = my_portfolio_returns.dot(weights)
# Display sample data
weighted_returns.plot(figsize= (25,15))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
df_all = pd.concat([portfolios_returns,my_portfolio_returns], axis = 'columns',join = 'inner')
df_all
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-01-03                   0.004658            0.000027
# 2018-01-04                  -0.000914            0.004196
# 2018-01-05                   0.004072            0.000823
# 2018-01-08                   0.004473           -0.003739
# 2018-01-09                  -0.001028            0.000872
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2018-01-03                     0.001979                0.005676 -0.000890
# 2018-01-04                     0.010743                0.004065 -0.000914
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
df_all.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# Algo 1                         0
# Algo 2                         0
# sp_tsx                         0
# L                              0
# OTEX                           0
# SHOP                           0
# dtype: int64

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
(df_all.std()*np.sqrt(252)).sort_values()
# Out:
# sp_tsx                         0.099121
# PAULSON & CO.INC.              0.114343
# Algo 1                         0.120028
# Algo 2                         0.137664
# SOROS FUND MANAGEMENT LLC      0.145675
# L                              0.162907
# TIGER GLOBAL MANAGEMENT LLC    0.219833
# OTEX                           0.225703
# BERKSHIRE HATHAWAY INC         0.227445
# SHOP                           0.504079
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
# Plot rolling standard deviation
df_all.rolling(window=120).std().plot(figsize= (25,15))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
df_corr = df_all.corr()
sns.heatmap(df_corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
# the correlation between choosed stocks
sns.heatmap(my_portfolio_returns.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot the 60-day Rolling Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate and plot Beta
df_withsp = df_all[['sp_tsx','L','OTEX','SHOP']]
df_withsp
# Out:
#               sp_tsx         L      OTEX      SHOP
# Date
# 2018-01-03  0.003774 -0.010002 -0.011703  0.023398
# 2018-01-04  0.002528  0.000174 -0.003715  0.017092
# 2018-01-05 -0.003869  0.000000 -0.007924 -0.001455
# 2018-01-08 -0.001944 -0.009753 -0.009631  0.016392
# 2018-01-09  0.000097  0.008969 -0.000712 -0.011254
# ...              ...       ...       ...       ...
# 2019-04-25 -0.000628  0.007398  0.006224 -0.003240
# 2019-04-26  0.002254 -0.003672  0.000773  0.012628
# 2019-04-29 -0.000788  0.002918 -0.006181  0.013173
# 2019-04-30 -0.001183  0.004900  0.000972  0.074941
# 2019-05-01 -0.004703 -0.019656  0.003301  0.016117
#
# [328 rows x 4 columns]

# %% [markdown]
# # There are two methods available to measure a stock’s beta. Both are expected to result in the same numerical outcome.
#
# ## **Method 1**
#
# Beta = Covariance / Variance: Where covariance is the stock’s return relative to the market's return. Variance shows how the stock moves in relation to the market. We used covariance to determine if the market and American Express moved in the same direction today.

# %%
stocks_lt = df_withsp.columns.tolist()[1:]
stocks_lt
# Out:
# ['L', 'OTEX', 'SHOP']

# %%
def get_beta_dict(df,market_index,stocks_lt):
    covariance = [df[x].cov(df[market_index]) for x in stocks_lt]
    variance = df[market_index].var()
    beta = [cov/variance for cov in covariance]
    beta_dict = dict(zip(stocks_lt,beta))
    return beta_dict

# %%
get_beta_dict(df_withsp,'sp_tsx',stocks_lt)
# Out:
# {'L': 0.5561370875605601, 'OTEX': 1.02601430826854, 'SHOP': 2.350843664393479}

# %%
def get_beta_individual(df,market_index,individual):
    covariance = df[individual].cov(df[market_index])
    variance = df[market_index].var()
    beta = covariance/variance
    return beta

# %%
for stock in stocks_lt:
    print(f"Beta of {stock}: {get_beta_individual(df_withsp,'sp_tsx',stock)}")
# Out:
# Beta of L: 0.5561370875605601
# Beta of OTEX: 1.02601430826854
# Beta of SHOP: 2.350843664393479

# %% [markdown]
# ## **Method 2**
#
# Beta: y= a + (b*x): Another way to calculate beta is to use a linear regression formula. Where beta is the coefficient of the independent variable (x in the equation), y is the dependent variable, a is the y-intercept or constant, and b is the slope of the line.

# %%
# In order to use pandas.rolling_apply(), the beta calculation function must produce a single value from an ndarray input
variance = df_withsp['sp_tsx'].var()
# Out:
# 3.898788619333669e-05

# %%
# 60-day Rolling Beta
sub_df = df_withsp[['L','OTEX','SHOP']]
sub_df.head()
# Out:
#                    L      OTEX      SHOP
# Date
# 2018-01-03 -0.010002 -0.011703  0.023398
# 2018-01-04  0.000174 -0.003715  0.017092
# 2018-01-05  0.000000 -0.007924 -0.001455
# 2018-01-08 -0.009753 -0.009631  0.016392
# 2018-01-09  0.008969 -0.000712 -0.011254

# %%
pd.rolling_apply(sub_df, 60, calc_beta,
# Out:
# {'L':             2018-01-03 00:00:00  2018-01-04 00:00:00  2018-01-05 00:00:00  \
#  Date
#  2018-01-03                  NaN                  NaN                  NaN
#  2018-01-04                  NaN                  NaN                  NaN
#  2018-01-05                  NaN                  NaN                  NaN
#  2018-01-08                  NaN                  NaN                  NaN
#  2018-01-09                  NaN                  NaN                  NaN
#  ...                         ...                  ...                  ...
#  2019-04-25                  NaN                  NaN                  NaN
#  2019-04-26                  NaN                  NaN                  NaN
#  2019-04-29                  NaN                  NaN                  NaN
#  2019-04-30                  NaN                  NaN                  NaN
#  2019-05-01                  NaN                  NaN                  NaN
#
# ...

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios

# %%
# Visualize the sharpe ratios as a bar plot

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!
